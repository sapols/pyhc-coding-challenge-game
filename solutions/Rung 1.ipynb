# %%
# !pip list

# %% [markdown]
# ## Rung 1

# %% [markdown]
# (1 min)

# %% [markdown]
# ### HAPI Client

# %% [markdown]
# #### Task 1: List Available HAPI Server URLs
#  - **Description:** Write a Python script that successfully imports the hapiclient package and lists all available HAPI server URLs.
#  - **Expected Learning Outcome:** Basic knowledge of Python imports, calling hapi() with no input args.
#  - **Hints:** The import statement is typically the first line in your Python script. Use the hapi() function.

# %%
# Idealized developer minutes: 1

import hapiclient
from hapiclient import hapi
servers = hapi()
servers
# Out:
# ['http://hapi-server.org/servers/SSCWeb/hapi',
#  'https://cdaweb.gsfc.nasa.gov/hapi',
#  'https://imag-data.bgs.ac.uk/GIN_V1/hapi',
#  'https://iswa.gsfc.nasa.gov/IswaSystemWebApp/hapi',
#  'http://lasp.colorado.edu/lisird/hapi',
#  'http://hapi-server.org/servers/TestData2.0/hapi',
#  'https://amda.irap.omp.eu/service/hapi',
#  'https://vires.services/hapi',
#  'https://api.helioviewer.org/hapi/Helioviewer/hapi',
#  'https://csatools.esac.esa.int/HapiServer/hapi']

# %% [markdown]
# #### Task 2: List Available CDAWeb Datasets
#  - **Description:** Use the hapiclient to connect to the CDAWeb HAPI server (https://cdaweb.gsfc.nasa.gov/hapi) and print the server's catalog of datasets.
#  - **Expected Learning Outcome:** Understanding how to establish a connection to a HAPI server and retrieve a list of available datasets.
#  - **Hints:** Refer to the hapiclient documentation or example notebooks for guidance on connecting to a server and retrieving the catalog.

# %%
# Idealized developer minutes: 1

from hapiclient import hapi
server = 'https://cdaweb.gsfc.nasa.gov/hapi'
catalog = hapi(server)
catalog
# Out:
# {'HAPI': '2.0',
#  'catalog': [{'id': 'A1_K0_MPA'},
#   {'id': 'A2_K0_MPA'},
#   {'id': 'AC_AT_DEF'},
#   {'id': 'AC_H0_MFI'},
#   {'id': 'AC_H0_SWE'},
#   {'id': 'AC_H1_EPM'},
#   {'id': 'AC_H1_MFI'},
#   {'id': 'AC_H1_SIS'},
#   {'id': 'AC_H2_CRIS'},
#   {'id': 'AC_H2_EPM'},
#   {'id': 'AC_H2_MFI'},
#   {'id': 'AC_H2_SEP'},
#   {'id': 'AC_H2_SIS'},
#   {'id': 'AC_H2_SWE'},
#   {'id': 'AC_H2_SWI'},
#   {'id': 'AC_H2_ULE'},
#   {'id': 'AC_H3_CRIS'},
#   {'id': 'AC_H3_EPM'},
#   {'id': 'AC_H3_MFI'},
#   {'id': 'AC_H3_SW2'},
#   {'id': 'AC_H3_SWI'},
#   {'id': 'AC_H4_SWI'},
#   {'id': 'AC_H5_SWI'},
#   {'id': 'AC_H6_SWI'},
#   {'id': 'AC_K0_EPM'},
#   {'id': 'AC_K0_MFI'},
#   {'id': 'AC_K0_SIS'},
#   {'id': 'AC_K0_SWE'},
#   {'id': 'AC_K1_EPM'},
#   {'id': 'AC_K1_MFI'},
#   {'id': 'AC_K1_SWE'},
#   {'id': 'AC_K2_MFI'},
#   {'id': 'AC_OR_DEF'},
#   {'id': 'AC_OR_SSC'},
#   {'id': 'AEROCUBE-6-A_DOSIMETER_L2'},
#   {'id': 'AEROCUBE-6-B_DOSIMETER_L2'},
#   {'id': 'ALOUETTE2_AV_LIM'},
# ...

# %% [markdown]
# #### Task 3: Reading OMNI HAPI Metadata
#  - **Description:** Access and display the metadata for all parameters of the "OMNI2_H0_MRG1HR" dataset from the CDAWeb HAPI server.
#  - **Expected Learning Outcome:** Familiarity with accessing and interpreting metadata from HAPI servers.
#  - **Hints:** Pass two things to the hapi() function.

# %%
# Idealized developer minutes: 1

from hapiclient import hapi

server = 'https://cdaweb.gsfc.nasa.gov/hapi'
dataset = 'OMNI2_H0_MRG1HR'
meta = hapi(server, dataset)
meta
# Out:
# {'HAPI': '2.0',
#  'resourceURL': 'https://cdaweb.gsfc.nasa.gov/misc/NotesO.html#OMNI2_H0_MRG1HR',
#  'contact': 'J.H. King, N. Papitashvili @ ADNET, NASA GSFC',
#  'parameters': [{'name': 'Time',
#    'length': 24,
#    'units': 'UTC',
#    'type': 'isotime',
#    'fill': None},
#   {'name': 'Rot1800',
#    'description': 'Bartels Rotation Number',
#    'units': '  ',
#    'type': 'integer',
#    'fill': '9999'},
#   {'name': 'IMF1800',
#    'description': 'OMNI ID code for the source spacecraft for time-shifted IMF values (see OMNI documentation link for codes)',
#    'units': None,
#    'type': 'integer',
#    'fill': '99'},
#   {'name': 'PLS1800',
#    'description': 'OMNI ID code for the source spacecraft for time-shifted IP plasma values (see OMNI documentation link for codes)',
#    'units': None,
#    'type': 'integer',
#    'fill': '99'},
#   {'name': 'IMF_PTS1800',
#    'description': '# fine time scale IMF points',
#    'units': None,
#    'type': 'integer',
# ...

# %% [markdown]
# ### Kamodo

# %% [markdown]
# #### Task 4: List CTIPe Model Variables
#  - **Description:** Import the Kamodo model wrapper and list all variables available for the model 'CTIPe'
#  - **Expected Learning Outcome:** Listing model variables.
#  - **Hints:** Use the Model_Variables() function.

# %%
# Idealized developer minutes: 1

import kamodo_ccmc.flythrough.model_wrapper as MW  
MW.Model_Variables('CTIPe')
# Out:
# The CTIPe model accepts the standardized variable names listed below.
# -----------------------------------------------------------------------------------
# E_avg : '['average energy', 32, 'GDZ', 'sph', ['time', 'lon', 'lat'], 'keV']'
# E_lambda140km : '['Electric field at 140 km, lambda component', 35, 'GDZ', 'sph', ['time', 'Elon', 'Elat'], 'V/m']'
# E_lambda300km : '['Electric field at 300 km, lambda component', 37, 'GDZ', 'sph', ['time', 'Elon', 'Elat'], 'V/m']'
# E_theta140km : '['Electric field at 140 km, theta component', 34, 'GDZ', 'sph', ['time', 'Elon', 'Elat'], 'V/m']'
# E_theta300km : '['Electric field at 300 km, theta component', 36, 'GDZ', 'sph', ['time', 'Elon', 'Elat'], 'V/m']'
# H_ilev : '['height dependent on primary pressure level', 4, 'GDZ', 'sph', ['time', 'lon', 'lat', 'ilev'], 'm']'
# H_ilev1 : '['height dependent on secondary pressure level', 5, 'GDZ', 'sph', ['time', 'lon', 'lat', 'ilev1'], 'm']'
# ...

# %% [markdown]
# ### pySPEDAS

# %% [markdown]
# #### Task 5: Set SPEDAS_DATA_DIR & Import pySPEDAS, PyTplot
#  - **Description:** Write a Python script that successfully sets the SPEDAS_DATA_DIR (which acts as a root data directory for all missions) then imports the pySPEDAS and pytplot package.
#  - **Expected Learning Outcome:** Basic knowledge of Python imports, understand how env var is root data dir for all missions.
#  - **Hints:** SPEDAS_DATA_DIR is a system environment variable.

# %%
# Idealized developer minutes: 1

import os
os.environ["SPEDAS_DATA_DIR"] = "/tmp/testpyspedas2"

# Import pyspedas and pytplot
import pyspedas
import pytplot

# See if it worked: load any type of data and verify in the log messages that it went to the expected place
pyspedas.themis.state(trange=["2023-03-24","2023-03-25"],probe="a")
# Out:
# ...
# Download complete: /tmp/testpyspedas2/themis/tha/l1/state/2023/tha_l1_state_20230324.cdf
# ['tha_pos',
#  'tha_vel',
#  'tha_spin_initial_delta_phi',
#  'tha_spin_idpu_spinper',
#  'tha_spin_segflags',
#  'tha_spin_ecl_initial_delta_phi',
#  'tha_spin_ecl_idpu_spinper',
#  'tha_spin_ecl_segflags',
#  'tha_pos_gse',
#  'tha_pos_gsm',
#  'tha_vel_gse',
#  'tha_vel_gsm',
#  'tha_pos_sel',
#  'tha_pos_sse',
#  'tha_vel_sel',
#  'tha_vel_sse']

# %% [markdown]
# #### Task 6: Load and Plot MMS FGM data
#  - **Description:** Using pySPEDAS/PyTplot, load and plot MMS FGM (fluxgate magnetometer) survey data for probe 1, for March 24, 2023.
#  - **Expected Learning Outcome:** Calling pyspedas.mission.instrument(), calling tplot()
#  - **Hints:** Syntax is “pyspedas.mission.instrument()” and "pytplot.tplot([‘varname’])"

# %%
import pyspedas
from pytplot import tplot

fgm_vars = pyspedas.mms.fgm(probe="1", trange=["2023-03-24","2023-03-25"], data_rate='srvy')
tplot('mms1_fgm_b_gse_srvy_l2')

# %% [markdown]
# ### pysat

# %% [markdown]
# #### Task 7: Set the pysat “data_dirs” Parameter
#
#  - **Description:** Set the pysat “data_dirs” parameter to something reasonable.
#  - **Expected Learning Outcome:** How to set the necessary data_dirs parameter.
#  - **Hints:** Pass something to pysat.params[].

# %%
# Idealized developer minutes: 1

import pysat

pysat.params['data_dirs'] = '.'

# %% [markdown]
# #### Task 8: Display Available pysatMadrigal Instruments
#  - **Description:** Display the different Instruments available in the pysatMadrigal package.
#  - **Expected Learning Outcome:** How to discover available pysat instruments.
#  - **Hints:** Use pysat.utils.display_available_instruments().

# %%
# Idealized developer minutes: 1

import pysat
import pysatMadrigal

pysat.utils.display_available_instruments(pysatMadrigal.instruments)
# Out:
# Instrument_Module      [Tag   Inst_ID]  Description
# ---------------------------------------------------
# pysatMadrigal.instruments.dmsp_ivm ['utd' 'f11']  UTDallas DMSP data processing
#                                    ['' 'f11']  Level 2 data processing
#                                    ['utd' 'f12']  UTDallas DMSP data processing
#                                    ['' 'f12']  Level 2 data processing
#                                    ['utd' 'f13']  UTDallas DMSP data processing
#                                    ['' 'f13']  Level 2 data processing
#                                    ['utd' 'f14']  UTDallas DMSP data processing
#                                    ['' 'f14']  Level 2 data processing
#                                    ['utd' 'f15']  UTDallas DMSP data processing
#                                    ['' 'f15']  Level 2 data processing
#                                    ['' 'f16']  Level 2 data processing
# ...

# %% [markdown]
# ### SunPy

# %% [markdown]
# #### Task 9: List Available SunPy Remote Data Sources
#  - **Description:** SunPy's Fido supports a number of different remote data sources. Display a list of them.
#  - **Expected Learning Outcome:** That the remote data sources can be listed by displaying the Fido object.
#  - **Hints:** Display the Fido object.

# %%
# Idealized developer minutes: 1

from sunpy.net import Fido, attrs as a
Fido
# Out:
# 15-May-24 16:13:51: /srv/conda/envs/notebook/lib/python3.10/site-packages/drms/version.py:25: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   for j, piece in enumerate(LooseVersion(version).version[:3]):
# ...
# sunpy.net.Fido
#
# Fido is a unified data search and retrieval tool.
#
# It provides simultaneous access to a variety of online data sources, some
# cover multiple instruments and data products like the Virtual Solar
# Observatory and some are specific to a single source.
#
# For details of using `~sunpy.net.Fido` see :ref:`sunpy-tutorial-acquiring-data-index`.
#
#
#       Client      ...
# ----------------- ...
# CDAWEBClient      ...
# EVEClient         ...
# GBMClient         ...
# XRSClient         ...
# SUVIClient        ...
# GONGClient        ...
# LYRAClient        ...
# NOAAIndicesClient ...
# NOAAPredictClient ...
# SRSClient         ...
# NoRHClient        ...
# RHESSIClient      ...
# HEKClient         ...
# ...

# %% [markdown]
# #### Task 10: List Available SunPy Instruments
#  - **Description:** SunPy's Fido supports a number of different instruments. Display a list of them.
#  - **Expected Learning Outcome:** That the instruments can be listed by displaying the `attrs.Instrument` object.
#  - **Hints:** Display the `attrs.Instrument` object.

# %%
# Idealized developer minutes: 1

from sunpy.net import Fido, attrs as a
a.Instrument
# Out:
# <class 'sunpy.net.attrs.Instrument'>
# sunpy.net.attrs.Instrument
#
# Specifies the Instrument name for the search.
#
#        Attribute Name       ...
# --------------------------- ...
# aia                         ...
# bcs                         ...
# be_continuum                ...
# be_halpha                   ...
# bigbear                     ...
# caii                        ...
# cds                         ...
# celias                      ...
# cerrotololo                 ...
# chp                         ...
# cook                        ...
# costep                      ...
# cp                          ...
# dpm                         ...
# eis                         ...
# eit                         ...
# elteide                     ...
# erne                        ...
# eui                         ...
# eve                         ...
# eve                         ...
# film                        ...
# five_12_channelmagnetograph ...
# ...

# %% [markdown]
# ### Misc.

# %% [markdown]
# #### Task 11: Count Closed PyHC Package Issues
#  - **Description:** Find and report the number of closed issues for a specified PyHC package. **For game: all core packages?**
#  - **Expected Learning Outcome:** How to discover that info on GitHub.
#  - **Hints:** Check the package’s GitHub page.

# %%
# Idealized developer minutes: 1 per package

# HAPI Client: https://github.com/hapi-server/client-python/issues?q=is%3Aissue+is%3Aclosed
# Kamodo: https://github.com/nasa/Kamodo/issues?q=is%3Aissue+is%3Aclosed
# PlasmaPy: https://github.com/PlasmaPy/PlasmaPy/issues?q=is%3Aissue+is%3Aclosed
# pysat: https://github.com/pysat/pysat/issues?q=is%3Aissue+is%3Aclosed
# pySPEDAS: https://github.com/spedas/pyspedas/issues?q=is%3Aissue+is%3Aclosed
# SpacePy: https://github.com/spacepy/spacepy/issues?q=is%3Aissue+is%3Aclosed
# SunPy: https://github.com/sunpy/sunpy/issues?q=is%3Aissue+is%3Aclosed

# %% [markdown]
# #### Task 12: Find PyHC Package Repository Contribution Rules
#  - **Description:** Find and give the link to the contribution rules for a specified PyHC package. **For game: PlasmaPy, pysat, pySPEDAS**
#  - **Expected Learning Outcome:** How do discover that info in a GitHub repo.
#  - **Hints:** Check the package's GitHub repo.

# %%
# Idealized developer minutes: 1 per package

# PlasmaPy: https://github.com/PlasmaPy/PlasmaPy/blob/main/CONTRIBUTING.md OR https://docs.plasmapy.org/en/latest/contributing/index.html
# pysat: https://github.com/pysat/pysat/blob/main/CONTRIBUTING.md
# pySPEDAS: https://github.com/spedas/pyspedas/blob/master/CONTRIBUTING.md
# SunPy: https://github.com/sunpy/sunpy/blob/main/README.rst#contributing OR https://docs.sunpy.org/en/latest/dev_guide/contents/newcomers.html

# %% [markdown]
# #### Task 13: Identify PyHC Packages License Types
#  - **Description:** Find the software license in a PyHC package repository and report what kind of license it is. **For game: find for _all_ core packages!**
#  - **Expected Learning Outcome:** How to find and identify software licenses.
#  - **Hints:** Check the package's GitHub repo.

# %%
# Idealized developer minutes: 1 per package

# HAPI Client: BSD 3-Clause "New" or "Revised" (https://github.com/hapi-server/client-python/blob/master/LICENSE.txt)
# Kamodo: NOSA Version 1.3 (https://github.com/nasa/Kamodo/blob/master/LICENSE)
# PlasmaPy: BSD 3-Clause "New" or "Revised" (https://github.com/PlasmaPy/PlasmaPy/blob/main/LICENSE.md)
# pysat: BSD 3-Clause "New" or "Revised" (https://github.com/pysat/pysat/blob/main/LICENSE)
# pySPEDAS: MIT License (https://github.com/spedas/pyspedas/blob/master/LICENSE.txt)
# SpacePy: Triad National Security, LLC (https://github.com/spacepy/spacepy/blob/main/LICENSE.md)
# SunPy: BSD 2-Clause "Simplified" (https://github.com/sunpy/sunpy/blob/main/LICENSE.rst)
